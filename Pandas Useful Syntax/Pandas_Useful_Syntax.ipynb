# %% [markdown]
# <a href="https://colab.research.google.com/github/Vite-Noiz/Machine-Learning-Course/blob/main/Pandas%20Useful%20Syntax/Pandas_Useful_Syntax.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# #1. creating a df

# %%
df = pd.DataFrame(columns=["age", "name", "id"])
df["age"] = [32, 26, 20, 24, 19, 31]
df["name"] = ["Joey", "Mark", "Raj", "Priya", "Sheldon", "Tom"]
df["id"] = [2, 5, 8, 1, 25, 3]
df["dob"] = ['01-01-1988', '02-11-1994', '04-10-2000',
             '31-12-1996', '02-06-2001', '07-03-1989']
df
# Out:
#    age     name  id         dob
# 0   32     Joey   2  01-01-1988
# 1   26     Mark   5  02-11-1994
# 2   20      Raj   8  04-10-2000
# 3   24    Priya   1  31-12-1996
# 4   19  Sheldon  25  02-06-2001
# 5   31      Tom   3  07-03-1989

# %% [markdown]
# #2. head-tail

# %%
print("top rows")
print(df.head(3))
print("bottom rows")
print(df.tail(3))
# Out:
# top rows
#    age  name  id         dob
# 0   32  Joey   2  01-01-1988
# 1   26  Mark   5  02-11-1994
# 2   20   Raj   8  04-10-2000
# bottom rows
#    age     name  id         dob
# 3   24    Priya   1  31-12-1996
# 4   19  Sheldon  25  02-06-2001
# 5   31      Tom   3  07-03-1989

# %% [markdown]
# #3. selecting a contiguous portion of df

# %%
print("showing 2 columns and 3 rows starting from the 2nd column 2nd row")
df_new = df.iloc[1:4, 1:3]
df_new
# Out:
# showing 2 columns and 3 rows starting from the 2nd column 2nd row
#     name  id
# 1   Mark   5
# 2    Raj   8
# 3  Priya   1

# %% [markdown]
# # 4. selecting some columns

# %%
print("showing id and age")
df_new = df[['id', 'age']]
df_new
# Out:
# showing id and age
#    id  age
# 0   2   32
# 1   5   26
# 2   8   20
# 3   1   24
# 4  25   19
# 5   3   31

# %% [markdown]
# #5. renaming columns

# %%
df.rename({"id":"col_1", "name":"col_2"},
          axis = "columns",
          inplace = True) # one by one
print(df)
df.columns = ["age", "name", "id", "dob"] # all at once
print(df)
# Out:
#    age    col_2  col_1         dob
# 0   32     Joey      2  01-01-1988
# 1   26     Mark      5  02-11-1994
# 2   20      Raj      8  04-10-2000
# 3   24    Priya      1  31-12-1996
# 4   19  Sheldon     25  02-06-2001
# 5   31      Tom      3  07-03-1989
#    age     name  id         dob
# 0   32     Joey   2  01-01-1988
# 1   26     Mark   5  02-11-1994
# 2   20      Raj   8  04-10-2000
# 3   24    Priya   1  31-12-1996
# 4   19  Sheldon  25  02-06-2001
# 5   31      Tom   3  07-03-1989

# %% [markdown]
# #6. splitting a string column

# %%
df[["day", "month", "year"]] = df["dob"].str.split("-", expand = True)
df
# Out:
#    age     name  id         dob day month  year
# 0   32     Joey   2  01-01-1988  01    01  1988
# 1   26     Mark   5  02-11-1994  02    11  1994
# 2   20      Raj   8  04-10-2000  04    10  2000
# 3   24    Priya   1  31-12-1996  31    12  1996
# 4   19  Sheldon  25  02-06-2001  02    06  2001
# 5   31      Tom   3  07-03-1989  07    03  1989

# %% [markdown]
# #7. concatenating string columns

# %%
df["mod_date"] = df["month"]+'-'+df["day"]+'-'+df["year"]
df
# Out:
#    age     name  id         dob day month  year    mod_date
# 0   32     Joey   2  01-01-1988  01    01  1988  01-01-1988
# 1   26     Mark   5  02-11-1994  02    11  1994  11-02-1994
# 2   20      Raj   8  04-10-2000  04    10  2000  10-04-2000
# 3   24    Priya   1  31-12-1996  31    12  1996  12-31-1996
# 4   19  Sheldon  25  02-06-2001  02    06  2001  06-02-2001
# 5   31      Tom   3  07-03-1989  07    03  1989  03-07-1989

# %% [markdown]
# #8. filtering with multiple criteria

# %%
df_new = df[
            (df["age"] <25) &
            (df["id"] >=3)
        ]
df_new
# Out:
#    age     name  id         dob day month  year    mod_date
# 2   20      Raj   8  04-10-2000  04    10  2000  10-04-2000
# 4   19  Sheldon  25  02-06-2001  02    06  2001  06-02-2001

# %% [markdown]
# #9. one hot encoding

# %%
df_new = pd.get_dummies(df,
                        prefix="mo",
                        prefix_sep='_',
                        columns=["month"],
                        drop_first=True)
df_new
# Out:
#    age     name  id         dob day  year    mod_date  mo_03  mo_06  mo_10  \
# 0   32     Joey   2  01-01-1988  01  1988  01-01-1988  False  False  False
# 1   26     Mark   5  02-11-1994  02  1994  11-02-1994  False  False  False
# 2   20      Raj   8  04-10-2000  04  2000  10-04-2000  False  False   True
# 3   24    Priya   1  31-12-1996  31  1996  12-31-1996  False  False  False
# 4   19  Sheldon  25  02-06-2001  02  2001  06-02-2001  False   True  False
# 5   31      Tom   3  07-03-1989  07  1989  03-07-1989   True  False  False
#
#    mo_11  mo_12
# 0  False  False
# 1   True  False
# 2  False  False
# 3  False   True
# 4  False  False
# 5  False  False

# %% [markdown]
# #10. continuos variable to categorical

# %%
df["cat_age"] = pd.cut(df["age"].values,
                       bins = [0, 30, 60],
                       labels = ["20's", "30's"])
df
# Out:
#    age     name  id         dob day month  year    mod_date cat_age
# 0   32     Joey   2  01-01-1988  01    01  1988  01-01-1988    30's
# 1   26     Mark   5  02-11-1994  02    11  1994  11-02-1994    20's
# 2   20      Raj   8  04-10-2000  04    10  2000  10-04-2000    20's
# 3   24    Priya   1  31-12-1996  31    12  1996  12-31-1996    20's
# 4   19  Sheldon  25  02-06-2001  02    06  2001  06-02-2001    20's
# 5   31      Tom   3  07-03-1989  07    03  1989  03-07-1989    30's

# %% [markdown]
# #11. apply( ) methood

# %%
df["name"] = df["name"].apply(lambda x : x.upper())
df
# Out:
#    age     name  id         dob day month  year    mod_date cat_age
# 0   32     JOEY   2  01-01-1988  01    01  1988  01-01-1988    30's
# 1   26     MARK   5  02-11-1994  02    11  1994  11-02-1994    20's
# 2   20      RAJ   8  04-10-2000  04    10  2000  10-04-2000    20's
# 3   24    PRIYA   1  31-12-1996  31    12  1996  12-31-1996    20's
# 4   19  SHELDON  25  02-06-2001  02    06  2001  06-02-2001    20's
# 5   31      TOM   3  07-03-1989  07    03  1989  03-07-1989    30's

# %%
df["even_odd"] = df["id"].apply(lambda x : 0 if x%2==0 else 1)
df
# Out:
#    age     name  id         dob day month  year    mod_date cat_age  even_odd
# 0   32     JOEY   2  01-01-1988  01    01  1988  01-01-1988    30's         0
# 1   26     MARK   5  02-11-1994  02    11  1994  11-02-1994    20's         1
# 2   20      RAJ   8  04-10-2000  04    10  2000  10-04-2000    20's         0
# 3   24    PRIYA   1  31-12-1996  31    12  1996  12-31-1996    20's         1
# 4   19  SHELDON  25  02-06-2001  02    06  2001  06-02-2001    20's         1
# 5   31      TOM   3  07-03-1989  07    03  1989  03-07-1989    30's         1

# %% [markdown]
# #Useful for checking overall structure of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       6 non-null      int64
#  1   name      6 non-null      object
#  2   id        6 non-null      int64
#  3   dob       6 non-null      object
#  4   day       6 non-null      object
#  5   month     6 non-null      object
#  6   year      6 non-null      object
#  7   mod_date  6 non-null      object
#  8   cat_age   6 non-null      category
#  9   even_odd  6 non-null      int64
# dtypes: category(1), int64(3), object(6)
# memory usage: 694.0+ bytes

# %%
df.describe()
# Out:
#              age         id  even_odd
# count   6.000000   6.000000  6.000000
# mean   25.333333   7.333333  0.666667
# std     5.428321   9.003703  0.516398
# min    19.000000   1.000000  0.000000
# 25%    21.000000   2.250000  0.250000
# 50%    25.000000   4.000000  1.000000
# 75%    29.750000   7.250000  1.000000
# max    32.000000  25.000000  1.000000
